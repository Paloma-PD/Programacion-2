# %%
# importing the required module
import seaborn as sns

# %%
# importing the dataset to be worked with
df = sns.load_dataset('tips') # se carga el dataset -tips- en la variable df
df.head() # muestra las primeras filas del dataset
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Creamos un histograsma de los datos de la columna - total_bill-
sns.displot(df['total_bill'], kde = False, color = "plum")
                                #kde = False, significa que no se suavisará la distribución

# %%
### COUNT PLOT
                                            # palette - permite personalizar el color de cada categoría
sns.countplot(x = 'sex', data = df, hue='sex', palette = ['lightblue', 'pink'])
                                    #hue - asigna colores diferentes a las barras basadas en la categoría
    # countplox - gráfico de barras que cuenta la frecuencia de cada categoría
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = 'day', data = df, hue ='day', palette ='Purples')
        # palette recibe los colores de las categorías como listas, o también cuenta con paletas predeterminadas
        # como 'Set1', 'Set2', 'Set3', 'Blues', 'Purples', 'RdYlBu', 'pastel', 'dark', 'muted'
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
### BARPLOT
sns.barplot(x = 'sex', y = 'total_bill', data = df, hue='sex', palette = ['lightblue', 'pink'])
# Genera un gráfico de barras que muestra el promedio de la columna 'total_bill'
#  para cada categoría en la columna 'sex'
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
### BOXPLOT
sns.boxplot(data = df, x = 'sex', y = 'total_bill', hue ='sex', palette = ['lightblue', 'pink'])
# Permite visualizar la distribución de un conjunto de datos numéricos a través de sus cuartiles
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
### REGRESSION PLOT
sns.lmplot(x = 'total_bill', y = 'tip', data = df,
           line_kws={'color': 'magenta'},  # Línea de regresión color magenta
           scatter_kws={'color': 'magenta'})   # Puntos color magenta
# rea un gráfico de dispersión (scatter plot) que muestra la relación entre las dos variables 
# 'total_bill' (el total de la cuenta) y 'tip' (la propina) del DataFrame df, 
# y ajusta una línea de regresión (por defecto, una línea de regresión lineal) a esos datos.

# %%
### MULTIVARIATE ANALYSIS
sns.pairplot(df)
# Crea un par de gráficos que muestra la relación entre todas las variables numéricas en el DataFrame

# %%
# Análisis multivariado por sexo
sns.pairplot(df, hue='sex', palette={'Male': 'lightblue', 'Female': 'pink'})

# %%
# Apply the default theme
sns.set_theme()

# Create the visualizations
                                           # col - Divide el gráfico en columnas según los valores de la columna     
sns.relplot(data = df, x = 'total_bill', y = 'tip', col = 'time', 
    # relplot - Crea un gráfico de relaciones entre variables
                            # size - Ajusta el tamaño de los puntos en el gráfico según la columna
            hue = 'smoker', style = 'smoker', size = 'size')
                        # style - Modifica el estilo de los puntos en el gráfico según la columna

# %%
# Cargamos un nuevo dataset DOTS
dots = sns.load_dataset('dots')
dots.head()
# Imprimimos los primeros registros del datset para conocerlo
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(data = dots, kind = 'line', x = 'time', y = 'firing_rate', col = 'align',
                        # kind - define el tipo de gráfico, otros tipos podrían ser scatter, hist, kde, bar
            hue = 'choice', size = 'coherence', style = 'choice',
            facet_kws = dict(sharex = False))
            # facet_kws - personaliza los aspectos del faceteo de los gráficos.
            # En false, significa que los gráficos de cada columna tendrán ejes X independientes,
            # lo que quiere decir que no compartirán el mismo rango de valores en el eje X. 
            # Esto es útil cuando los diferentes subconjuntos de los datos tienen rangos diferentes.

# %%
# Cargamos un nuevo dataset  FMRI
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
### STATISTICAL ESTIMATION
sns.relplot(data = fmri, kind = 'line', x = 'timepoint', y = 'signal', col = 'region',
           hue = 'event', style = 'event')

# %%
# Regresamos al dataset TIPS
sns.lmplot(data = df, x = 'total_bill', y = 'tip', col = 'time', hue = 'smoker')

# %%
### DISTRIBUTIONAL REPRESENTATIONS
sns.displot(data = df, x = 'total_bill', col = 'time', kde = True)

# %%
# Cargamos un nuevo dataset
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
### MULTIVARIATE VIEWS ON COMPLEX DATASETS
sns.jointplot(data = penguins, x = 'flipper_length_mm',
              y = 'bill_length_mm', hue = 'species', palette = "Pastel1")

# jointplot - genera una visualización que combina un gráfico de dispersión (scatter plot) 
# entre dos variables numéricas y sus respectivas distribuciones univariantes 
# (a través de histogramas o gráficos de densidad) en los márgenes del gráfico.
# Es útil para explorar la relación entre dos variables, así como las distribuciones 
# de esas variables de manera conjunta.
